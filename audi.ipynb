# %% [markdown]
# # Audi

# %%
import io
import re
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col 
from statsmodels.iolib.summary2 import summary_params 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
audi = pd.read_csv('https://raw.githubusercontent.com/zhanna11111/homework111111/main/audi.csv')
audi
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
sns.pairplot(audi)

# %%
audi = smf.ols(formula='price~mileage+fuelType+year+transmission+tax+engineSize', data=audi).fit()
audi.params
# Out:
# Intercept                   -4.454120e+06
# fuelType[T.Hybrid]           1.011053e+04
# fuelType[T.Petrol]           2.471821e+03
# transmission[T.Manual]      -2.169872e+03
# transmission[T.Semi-Auto]   -6.913467e+02
# mileage                     -1.078788e-01
# year                         2.209155e+03
# tax                         -2.314005e-01
# engineSize                   1.220196e+04
# dtype: float64

# %% [markdown]
# При увеличении пробега на 100 км, цена автомобиля падает на 1,7 тыс евро

# %%
audi.ess.round(3)
# Out:
# 1117814099724.529

# %%
audi.centered_tss.round(3)
# Out:
# 1463912630863.732

# %%
audi.centered_tss.round(3)
# Out:
# 1463912630863.732
